# %%
import pandas as pd

df = pd.read_csv('SpotifyFeatures.csv')
df['genre'] = df['genre'].str.replace('Children’s Music', "Children's Music")

target = 'genre'
X = df.drop(columns=[target, 'track_name'])
X = X.drop(columns=['track_id'])
y = df[target]

# %%
df['genre'].nunique()
# Out:
# 26

# %%
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
numeric_features
# Out:
# ['popularity',
#  'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'tempo',
#  'valence']

# %%
categories_features = X.select_dtypes(include=['object']).columns.tolist()
categories_for_TE = ['artist_name']
categories_features = list(set(categories_features) - set(categories_for_TE))

# %%
# Out:
# ['mode', 'time_signature', 'key']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y ,random_state=42,
                                                    test_size=0.2)

# %%
# преобразуем artist_name TargetEncoder, чтоб было меньше столбцов

import category_encoders as ce

TE_encoder = ce.TargetEncoder(cols=['artist_name'], smoothing=1.0)
X_train_TE = TE_encoder.fit_transform(X_train[['artist_name']], Y_train)
X_test_TE = TE_encoder.transform(X_test[['artist_name']])

X_train_modified = X_train.copy()
X_test_modified = X_test.copy()

X_train_modified['artist_name'] = X_train_TE['artist_name']
X_test_modified['artist_name'] = X_test_TE['artist_name']

numeric_features = numeric_features + ['artist_name'] 
categories_features = [col for col in categories_features 
                              if col != 'artist_name']
print(f"Обновлённые числовые признаки: {numeric_features}")
print(f"Обновлённые категориальные признаки: {categories_features}")
# Out:
# Обновлённые числовые признаки: ['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'artist_name']
# Обновлённые категориальные признаки: ['mode', 'time_signature', 'key']

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from category_encoders import TargetEncoder
numeric_transform = Pipeline([
    ('nan_imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categories_transformer = Pipeline([
    ('nan_imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])


preprosessor = ColumnTransformer([
    ('num', numeric_transform, numeric_features),
    ('cat', categories_transformer, categories_features)
])

# %%
X_train['artist_name'].nunique()
# Out:
# 13748

# %%
preprosessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('nan_imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['popularity', 'acousticness', 'danceability',
#                                   'duration_ms', 'energy', 'instrumentalness',
#                                   'liveness', 'loudness', 'speechiness',
#                                   'tempo', 'valence']),
#                                 ('cat',
#                                  Pipeline(steps=[('nan_imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['artist_name', 'key', 'mode',
#                                   'time_signature'])])

# %%
X_train_proc = preprosessor.transform(X_train)
X_test_proc = preprosessor.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(
    n_neighbors=34,
    weights='distance',
    algorithm='auto',
    leaf_size=66,
    metric='manhattan',
    n_jobs=-1
)

# %%
#Итоговый гипер-пайплайнчик
clf = Pipeline([
    ('preproc', preprosessor),
    ('classifier', knn)
])

# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("Spotify")
# Out:
# <Experiment: artifact_location=('file:///C:/Users/Artem/Desktop/vs code project/KNN, '
#  'ANN/mlflow_server/artefacts/848808723939071173'), creation_time=1753901309241, experiment_id='848808723939071173', last_update_time=1753901309241, lifecycle_stage='active', name='Spotify', tags={}>

# %%
X_train_modified
# Out:
#         artist_name  popularity  acousticness  danceability  duration_ms  \
# 45184     12.760436          20      0.000014         0.417       232453
# 223673    12.739746          57      0.012000         0.494       227227
# 138964    19.993408          78      0.423000         0.807       297485
# 125920    14.599567          45      0.978000         0.190       160227
# 117862    12.764047          54      0.000853         0.886       194675
# ...             ...         ...           ...           ...          ...
# 129407     5.000000          28      0.994000         0.357       380627
# 68992     14.466019          58      0.072700         0.660       227347
# 18871     14.756757          55      0.480000         0.862       212683
# 172541     6.000000          18      0.782000         0.485       148250
# 29919     12.764044          28      0.318000         0.447       252200
#
#         energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 45184   0.9060          0.001460   C    0.1540    -5.453  Major       0.2430
# 223673  0.9130          0.000000   E    0.0702    -6.220  Minor       0.0477
# 138964  0.6810          0.000000   B    0.0962    -6.268  Major       0.0983
# 125920  0.1670          0.046600  G#    0.1740   -13.944  Major       0.0471
# 117862  0.3540          0.000000  C#    0.0731   -15.511  Major       0.5520
# ...        ...               ...  ..       ...       ...    ...          ...
# 129407  0.0074          0.872000  C#    0.0980   -31.676  Major       0.0435
# 68992   0.8750          0.000037  A#    0.3580    -6.057  Minor       0.0889
# 18871   0.4770          0.000000   F    0.1050    -9.393  Minor       0.3310
# 172541  0.5170          0.000000  F#    0.6140   -19.929  Major       0.9430
# 29919   0.7230          0.000000   E    0.2520    -4.204  Major       0.0301
#
#           tempo time_signature  valence
# 45184   165.087            4/4   0.2490
# 223673  155.880            4/4   0.6630
# 138964  140.006            4/4   0.6760
# 125920   86.607            3/4   0.0382
# 117862  100.055            4/4   0.2320
# ...         ...            ...      ...
# 129407  118.160            3/4   0.1360
# 68992   120.034            4/4   0.6110
# 18871   123.034            4/4   0.6070
# 172541   71.935            3/4   0.2950
# 29919    77.994            4/4   0.3230
#
# [186180 rows x 15 columns]

# %%
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import TruncatedSVD

X_train_small, _, y_train_small, _ = train_test_split(X_train_modified, Y_train, stratify=Y_train ,random_state=42,
                                                    test_size=0.5)



def objective(trial):
    params = {
        'n_neighbors': trial.suggest_int('n_neighbors', 3, 50),
        'weights': trial.suggest_categorical('weights', ['uniform', 'distance']),
        'metric': trial.suggest_categorical('metric', ['cosine', 'euclidean']),# 'manhattan']),
        'leaf_size': trial.suggest_int('leaf_size', 10, 100)
    }
    
    model = KNeighborsClassifier(**params)
    pipe = Pipeline([('preproc', preprosessor), 
                     #('svd', TruncatedSVD(n_components=500)),
                        ('classifier', model)])
    return cross_val_score(pipe, X_train_small, y_train_small, 
                         cv=5, scoring='accuracy', n_jobs=7).mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)  
#c OHE получаем 13000+ признаков и ломается, из за слишком разряженных данных
# Out:
# [I 2025-07-31 20:50:35,629] A new study created in memory with name: no-name-9cee1624-4587-4129-b83b-d004844e7d5a
# [I 2025-07-31 20:51:20,497] Trial 0 finished with value: 0.3985283059404877 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'metric': 'cosine', 'leaf_size': 83}. Best is trial 0 with value: 0.3985283059404877.
# [I 2025-07-31 20:51:28,925] Trial 1 finished with value: 0.4210334085293802 and parameters: {'n_neighbors': 43, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 18}. Best is trial 1 with value: 0.4210334085293802.
# [I 2025-07-31 20:52:08,677] Trial 2 finished with value: 0.41631754216349764 and parameters: {'n_neighbors': 45, 'weights': 'distance', 'metric': 'cosine', 'leaf_size': 84}. Best is trial 1 with value: 0.4210334085293802.
# [I 2025-07-31 20:52:15,864] Trial 3 finished with value: 0.42131270813191535 and parameters: {'n_neighbors': 42, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 85}. Best is trial 3 with value: 0.42131270813191535.
# [I 2025-07-31 20:52:56,936] Trial 4 finished with value: 0.4161349231926093 and parameters: {'n_neighbors': 49, 'weights': 'distance', 'metric': 'cosine', 'leaf_size': 31}. Best is trial 3 with value: 0.42131270813191535.
# [I 2025-07-31 20:53:05,768] Trial 5 finished with value: 0.4459555269094425 and parameters: {'n_neighbors': 24, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 34}. Best is trial 5 with value: 0.4459555269094425.
# [I 2025-07-31 20:53:13,868] Trial 6 finished with value: 0.4210334085293802 and parameters: {'n_neighbors': 43, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 58}. Best is trial 5 with value: 0.4459555269094425.
# [I 2025-07-31 20:53:54,850] Trial 7 finished with value: 0.43846814910301857 and parameters: {'n_neighbors': 17, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 38}. Best is trial 5 with value: 0.4459555269094425.
# [I 2025-07-31 20:54:36,653] Trial 8 finished with value: 0.447599097647438 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 64}. Best is trial 8 with value: 0.447599097647438.
# [I 2025-07-31 20:54:45,403] Trial 9 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 79}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:54:53,942] Trial 10 finished with value: 0.4510258889246965 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 97}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:02,553] Trial 11 finished with value: 0.4510258889246965 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 98}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:11,185] Trial 12 finished with value: 0.4510258889246965 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 98}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:19,810] Trial 13 finished with value: 0.4510258889246965 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 74}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:28,434] Trial 14 finished with value: 0.4467074873778064 and parameters: {'n_neighbors': 25, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 69}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:37,283] Trial 15 finished with value: 0.45103663121710175 and parameters: {'n_neighbors': 36, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 51}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:46,122] Trial 16 finished with value: 0.4519174991943281 and parameters: {'n_neighbors': 38, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 48}. Best is trial 9 with value: 0.4533569663766248.
# [I 2025-07-31 20:55:54,492] Trial 17 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 48}. Best is trial 17 with value: 0.4537007197335911.
# [I 2025-07-31 20:56:02,512] Trial 18 finished with value: 0.44177677516382 and parameters: {'n_neighbors': 19, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 15}. Best is trial 17 with value: 0.4537007197335911.
# [I 2025-07-31 20:56:11,302] Trial 19 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 42}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:56:19,709] Trial 20 finished with value: 0.37483080889461806 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 45}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:56:28,398] Trial 21 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 56}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:56:37,045] Trial 22 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 58}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:56:45,963] Trial 23 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 25}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:56:54,543] Trial 24 finished with value: 0.45232570630572566 and parameters: {'n_neighbors': 39, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 41}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:57:03,069] Trial 25 finished with value: 0.4519604683639488 and parameters: {'n_neighbors': 41, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 54}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:57:46,423] Trial 26 finished with value: 0.4477280051563004 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 63}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:57:55,172] Trial 27 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 27}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:58:03,575] Trial 28 finished with value: 0.4482866043613708 and parameters: {'n_neighbors': 29, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 44}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:58:46,615] Trial 29 finished with value: 0.4028359651949726 and parameters: {'n_neighbors': 10, 'weights': 'distance', 'metric': 'cosine', 'leaf_size': 38}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:58:55,591] Trial 30 finished with value: 0.45270168653990756 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 55}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:59:04,200] Trial 31 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 63}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:59:12,878] Trial 32 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 57}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:59:21,605] Trial 33 finished with value: 0.45206789128800084 and parameters: {'n_neighbors': 40, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 50}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:59:29,699] Trial 34 finished with value: 0.4210334085293802 and parameters: {'n_neighbors': 43, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 69}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 20:59:37,691] Trial 35 finished with value: 0.42062520141798265 and parameters: {'n_neighbors': 48, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 23}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:00:21,252] Trial 36 finished with value: 0.447599097647438 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 32}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:00:29,018] Trial 37 finished with value: 0.4199054678268343 and parameters: {'n_neighbors': 37, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 60}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:00:37,345] Trial 38 finished with value: 0.45235793318294126 and parameters: {'n_neighbors': 43, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 45}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:01:19,711] Trial 39 finished with value: 0.447813943495542 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 37}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:01:27,553] Trial 40 finished with value: 0.4210334085293802 and parameters: {'n_neighbors': 43, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 71}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:01:36,096] Trial 41 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 29}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:01:44,519] Trial 42 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 11}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:01:53,043] Trial 43 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 48}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:02:01,454] Trial 44 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 19}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:02:09,817] Trial 45 finished with value: 0.45270168653990756 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 53}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:02:18,080] Trial 46 finished with value: 0.4519604683639488 and parameters: {'n_neighbors': 41, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 26}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:00,603] Trial 47 finished with value: 0.447813943495542 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 36}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:08,607] Trial 48 finished with value: 0.4433451498549791 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 92}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:17,448] Trial 49 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 41}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:25,836] Trial 50 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 79}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:34,192] Trial 51 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 22}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:42,582] Trial 52 finished with value: 0.4525190675690192 and parameters: {'n_neighbors': 44, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 60}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:51,043] Trial 53 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 28}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:03:59,521] Trial 54 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 33}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:04:07,853] Trial 55 finished with value: 0.4324094961864862 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 42}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:04:16,411] Trial 56 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 13}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:04:24,664] Trial 57 finished with value: 0.4526372327854764 and parameters: {'n_neighbors': 42, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 12}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:06,828] Trial 58 finished with value: 0.4451498549790525 and parameters: {'n_neighbors': 35, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 18}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:14,382] Trial 59 finished with value: 0.417896659147062 and parameters: {'n_neighbors': 29, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 66}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:22,943] Trial 60 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 16}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:31,252] Trial 61 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 24}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:39,652] Trial 62 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 23}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:47,921] Trial 63 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 14}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:05:56,105] Trial 64 finished with value: 0.4525190675690192 and parameters: {'n_neighbors': 44, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 14}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:04,287] Trial 65 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 21}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:12,621] Trial 66 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 15}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:20,970] Trial 67 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 20}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:29,513] Trial 68 finished with value: 0.45206789128800084 and parameters: {'n_neighbors': 40, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 19}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:37,856] Trial 69 finished with value: 0.4525190675690192 and parameters: {'n_neighbors': 44, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 24}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:46,419] Trial 70 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 10}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:06:54,773] Trial 71 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 10}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:07:03,131] Trial 72 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 10}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:07:11,492] Trial 73 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 13}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:07:20,065] Trial 74 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 16}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:07:28,650] Trial 75 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 20}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:07:37,096] Trial 76 finished with value: 0.45270168653990756 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 17}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:08:18,999] Trial 77 finished with value: 0.4159093350521001 and parameters: {'n_neighbors': 47, 'weights': 'distance', 'metric': 'cosine', 'leaf_size': 10}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:08:27,567] Trial 78 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 29}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:08:35,950] Trial 79 finished with value: 0.4526372327854764 and parameters: {'n_neighbors': 42, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 13}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:08:44,309] Trial 80 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 23}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:08:52,859] Trial 81 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 14}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:01,312] Trial 82 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 12}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:09,658] Trial 83 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 17}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:17,757] Trial 84 finished with value: 0.3866688151251477 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 10}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:26,454] Trial 85 finished with value: 0.4525190675690192 and parameters: {'n_neighbors': 44, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 20}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:34,736] Trial 86 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 25}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:43,104] Trial 87 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 14}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:09:50,631] Trial 88 finished with value: 0.4164786765495757 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'metric': 'euclidean', 'leaf_size': 21}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:10:34,056] Trial 89 finished with value: 0.447599097647438 and parameters: {'n_neighbors': 45, 'weights': 'uniform', 'metric': 'cosine', 'leaf_size': 18}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:10:42,750] Trial 90 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 31}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:10:51,038] Trial 91 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 12}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:10:59,575] Trial 92 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 21}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:08,019] Trial 93 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 15}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:16,370] Trial 94 finished with value: 0.45372220431840155 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 35}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:24,669] Trial 95 finished with value: 0.4533569663766248 and parameters: {'n_neighbors': 47, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 27}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:32,968] Trial 96 finished with value: 0.4537007197335911 and parameters: {'n_neighbors': 50, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 19}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:41,365] Trial 97 finished with value: 0.4533354817918144 and parameters: {'n_neighbors': 46, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 23}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:49,742] Trial 98 finished with value: 0.45363626597915996 and parameters: {'n_neighbors': 48, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 12}. Best is trial 19 with value: 0.45372220431840155.
# [I 2025-07-31 21:11:56,564] Trial 99 finished with value: 0.4525190675690192 and parameters: {'n_neighbors': 44, 'weights': 'uniform', 'metric': 'euclidean', 'leaf_size': 13}. Best is trial 19 with value: 0.45372220431840155.

# %%
X_train_modified.head()
# Out:
#         artist_name  popularity  acousticness  danceability  duration_ms  \
# 45184     12.760436          20      0.000014         0.417       232453
# 223673    12.739746          57      0.012000         0.494       227227
# 138964    19.993408          78      0.423000         0.807       297485
# 125920    14.599567          45      0.978000         0.190       160227
# 117862    12.764047          54      0.000853         0.886       194675
#
#         energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 45184    0.906           0.00146   C    0.1540    -5.453  Major       0.2430
# 223673   0.913           0.00000   E    0.0702    -6.220  Minor       0.0477
# 138964   0.681           0.00000   B    0.0962    -6.268  Major       0.0983
# 125920   0.167           0.04660  G#    0.1740   -13.944  Major       0.0471
# 117862   0.354           0.00000  C#    0.0731   -15.511  Major       0.5520
#
#           tempo time_signature  valence
# 45184   165.087            4/4   0.2490
# 223673  155.880            4/4   0.6630
# 138964  140.006            4/4   0.6760
# 125920   86.607            3/4   0.0382
# 117862  100.055            4/4   0.2320

# %%
import mlflow 
import mlflow.sklearn as ms
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

with mlflow.start_run(run_name='KNN_TE3'):
    n_neighbors, leaf_size, weights, metric = 49, 42, 'uniform', 'euclidean'
    mlflow.log_param('n_neighbors', n_neighbors)
    mlflow.log_param("weights", weights)
    mlflow.log_param("metric", metric)
    mlflow.log_param("leaf_size", leaf_size)

    knn1 = KNeighborsClassifier(
        n_neighbors=n_neighbors,
        weights=weights,
        algorithm='auto',
        leaf_size=leaf_size,
        metric=metric,
        n_jobs=-1
    )
    clf = Pipeline([
        ('preproc', preprosessor),
        ('classifier', knn1)
    ])
    clf.fit(X_train_modified, Y_train)
    y_pred = clf.predict(X_test_modified)

    mlflow.log_metric("accuracy", accuracy_score(Y_test, y_pred))
    mlflow.log_metric("precision", precision_score(Y_test, y_pred, average='weighted'))
    mlflow.log_metric("recall", recall_score(Y_test, y_pred, average='weighted'))
    mlflow.log_metric("f1", f1_score(Y_test, y_pred, average='weighted'))

    cl_rep = classification_report(y_true=Y_test, y_pred=y_pred)

    ms.log_model(clf, 'knn1')

    with open('classification_report.txt', 'w') as file:
        file.write(cl_rep)
    mlflow.log_artifact("classification_report.txt")
mlflow.end_run()
