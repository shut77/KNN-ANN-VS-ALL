# %%
import pandas as pd

df = pd.read_csv('SpotifyFeatures.csv')

target = 'genre'
X = df.drop(columns=[target, 'track_name'])
y = df[target]

# %%
X = X.drop(columns=['track_id'])
X.head()
# Out:
#          artist_name  popularity  acousticness  danceability  duration_ms  \
# 0     Henri Salvador           0         0.611         0.389        99373
# 1  Martin & les fées           1         0.246         0.590       137373
# 2    Joseph Williams           3         0.952         0.663       170267
# 3     Henri Salvador           0         0.703         0.240       152427
# 4       Fabien Nataf           4         0.950         0.331        82625
#
#    energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 0   0.910             0.000  C#    0.3460    -1.828  Major       0.0525
# 1   0.737             0.000  F#    0.1510    -5.559  Minor       0.0868
# 2   0.131             0.000   C    0.1030   -13.879  Minor       0.0362
# 3   0.326             0.000  C#    0.0985   -12.178  Major       0.0395
# 4   0.225             0.123   F    0.2020   -21.150  Major       0.0456
#
#      tempo time_signature  valence
# 0  166.969            4/4    0.814
# 1  174.003            4/4    0.816
# 2   99.488            5/4    0.368
# 3  171.758            4/4    0.227
# 4  140.576            4/4    0.390

# %%
y.head()
# Out:
# 0    Movie
# 1    Movie
# 2    Movie
# 3    Movie
# 4    Movie
# Name: genre, dtype: object

# %%
X.dtypes
# Out:
# artist_name          object
# popularity            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# time_signature       object
# valence             float64
# dtype: object

# %%
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
numeric_features
# Out:
# ['popularity',
#  'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'tempo',
#  'valence']

# %%
categories_features = X.select_dtypes(include=['object']).columns.tolist()
categories_features
# Out:
# ['artist_name', 'key', 'mode', 'time_signature']

# %%
un = df[categories_features]
uni_cat = un.nunique()
uni_cat, len(df['artist_name'])
# Out:
# (artist_name       14564
#  key                  12
#  mode                  2
#  time_signature        5
#  dtype: int64,
#  232725)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
numeric_transform = Pipeline([
    ('nan_imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categories_transformer = Pipeline([
    ('nan_imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprosessor = ColumnTransformer([
    ('num', numeric_transform, numeric_features),
    ('cat', categories_transformer, categories_features)
])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y ,random_state=42,
                                                    test_size=0.2)

# %%
X_train.head()
# Out:
#               artist_name  popularity  acousticness  danceability  \
# 30142                 OxT          25      0.029600         0.502
# 157325             Rancid          40      0.180000         0.411
# 5389            Disturbed          52      0.000116         0.589
# 205668         Tom Tykwer          21      0.281000         0.143
# 202563  Alexandre Desplat          33      0.907000         0.128
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 30142        217880   0.961          0.000381  D#    0.1070    -5.302  Minor
# 157325       152760   0.958          0.000002   G    0.1260    -3.291  Major
# 5389         191960   0.983          0.002110  A#    0.0628    -2.521  Minor
# 205668       213970   0.207          0.773000  C#    0.1130   -14.786  Major
# 202563        32173   0.136          0.944000  A#    0.1190   -16.687  Minor
#
#         speechiness    tempo time_signature  valence
# 30142        0.0840  140.015            4/4   0.6240
# 157325       0.0812  171.686            4/4   0.7770
# 5389         0.1210  110.007            4/4   0.4690
# 205668       0.0362  168.028            4/4   0.0646
# 202563       0.0363  147.175            4/4   0.1390

# %%
X_train['artist_name'].nunique()
# Out:
# 13738

# %%
preprosessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('nan_imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['popularity', 'acousticness', 'danceability',
#                                   'duration_ms', 'energy', 'instrumentalness',
#                                   'liveness', 'loudness', 'speechiness',
#                                   'tempo', 'valence']),
#                                 ('cat',
#                                  Pipeline(steps=[('nan_imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['artist_name', 'key', 'mode',
#                                   'time_signature'])])

# %%
X_train_proc = preprosessor.transform(X_train)
X_test_proc = preprosessor.transform(X_test)

# %%
X_train_proc.shape, np.mean(X_train_proc, axis=0)
# Out:
# ((186180, 13768),
#  matrix([[-3.56287469e-17,  3.93082580e-17, -3.54502770e-16, ...,
#            1.03684606e-01,  8.62283811e-01,  2.26501235e-02]]))

# %%
X_train_proc[:3,3939].toarray()
# Out:
# array([[0.],
#        [0.],
#        [0.]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(
    n_neighbors=5,
    weights='uniform',
    algorithm='auto',
    leaf_size=30,
    p=2,
    metric='minkowski',
    n_jobs=-1
)

# %%
#Итоговый гипер-пайплайнчик
clf = Pipeline([
    ('preproc', preprosessor),
    ('classifier', knn)
])

# %%
clf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preproc',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('nan_imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['popularity', 'acousticness',
#                                                    'danceability',
#                                                    'duration_ms', 'energy',
#                                                    'instrumentalness',
#                                                    'liveness', 'loudness',
#                                                    'speechiness', 'tempo',
#                                                    'valence']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('nan_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['artist_name', 'key', 'mode',
#                                                    'time_signature'])])),
#                 ('classifier', KNeighborsClassifier(n_jobs=-1))])

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
cl_rep = classification_report(y_true=Y_test, y_pred=y_pred)

# %%
print(cl_rep)
# Out:
#                   precision    recall  f1-score   support
#
#        A Capella       0.32      0.25      0.28        24
#      Alternative       0.09      0.21      0.12      1853
#            Anime       0.51      0.64      0.57      1787
#            Blues       0.31      0.39      0.34      1805
# Children's Music       0.82      0.83      0.82      1081
# Children’s Music       0.05      0.07      0.06      1871
#        Classical       0.59      0.63      0.61      1851
#           Comedy       0.95      0.95      0.95      1936
#          Country       0.31      0.45      0.37      1733
#            Dance       0.15      0.19      0.17      1740
#       Electronic       0.52      0.47      0.50      1875
#             Folk       0.21      0.20      0.21      1860
#          Hip-Hop       0.19      0.22      0.20      1859
#            Indie       0.10      0.06      0.07      1909
#             Jazz       0.43      0.35      0.39      1888
#            Movie       0.69      0.59      0.64      1561
#            Opera       0.74      0.86      0.79      1656
#              Pop       0.16      0.12      0.14      1877
#              R&B       0.12      0.08      0.10      1798
#              Rap       0.11      0.06      0.08      1846
#           Reggae       0.51      0.45      0.48      1754
#        Reggaeton       0.60      0.56      0.58      1785
#             Rock       0.16      0.09      0.12      1855
#              Ska       0.70      0.59      0.64      1775
#             Soul       0.18      0.09      0.12      1818
#       Soundtrack       0.68      0.69      0.68      1929
#            World       0.54      0.42      0.47      1819
#
#         accuracy                           0.38     46545
#        macro avg       0.40      0.39      0.39     46545
#     weighted avg       0.39      0.38      0.38     46545
